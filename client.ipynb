# %%
from vantage6.client import Client

# Setup the client
client = Client("https://blueberry.vantage6.ai", 443, "")
client.authenticate("frank-root", "BZ21iRVl3qXgjbfBh1hb!", mfa_code="973114")
# Out:
#  Welcome to
#                   _                     __
#                  | |                   / /
# __   ____ _ _ __ | |_ __ _  __ _  ___ / /_
# \ \ / / _` | '_ \| __/ _` |/ _` |/ _ \ '_ \
#  \ V / (_| | | | | || (_| | (_| |  __/ (_) |
#   \_/ \__,_|_| |_|\__\__,_|\__, |\___|\___/
#                             __/ |
#                            |___/
#
#  --> Join us on Discord! https://discord.gg/rwRvwyK
#  --> Docs: https://docs.vantage6.ai
#  --> Blog: https://vantage6.ai
# ------------------------------------------------------------
# Cite us!
# If you publish your findings obtained using vantage6,
# please cite the proper sources as mentioned in:
# https://vantage6.ai/vantage6/references
# ------------------------------------------------------------
# Successfully authenticated
#  --> Succesfully authenticated
#  --> Name: Frank (id=10)
#  --> Organization: root (id=1)

# %%
client.task.get(1064)
# Out:
# {'databases': [{'label': 'omop', 'parameters': '{}'}],
#  'collaboration': {'id': 1,
#   'link': '/collaboration/1',
#   'methods': ['PATCH', 'DELETE', 'GET']},
#  'status': 'completed',
#  'children': '/task?parent_id=1064',
#  'job_id': 729,
#  'runs': '/run?task_id=1064',
#  'description': '@',
#  'init_org': {'id': 2, 'link': '/organization/2', 'methods': ['PATCH', 'GET']},
#  'id': 1064,
#  'parent': None,
#  'init_user': {'id': 6,
#   'link': '/user/6',
#   'methods': ['PATCH', 'DELETE', 'GET']},
#  'name': '[RERUN] Create cohorts study-a-thon',
#  'image': 'harbor2.vantage6.ai/blueberry/omop-cohorts',
#  'study': None,
#  'results': '/result?task_id=1064',
#  'created_at': '2024-07-02T11:03:36.705012'}

# %%
client.run.from_task(1064)["data"][0]["input"]
# Out:
# --> Attempting to decrypt results!
# ...
